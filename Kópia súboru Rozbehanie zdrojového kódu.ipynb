# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/My Drive/Bakalarka-Peter_Sipos' 
# replace with your Github username 
GIT_USERNAME = "peter-sipos" 
# definitely replace with your
GIT_TOKEN = "{7ebee1f88ec9b82612e41eb481a2bfc9b6f548d4}"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "Learning-to-See-in-the-Dark" 

PROJECT_PATH = '/content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation'

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# /content/drive
# ('PROJECT_PATH: ', '/content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation')
# ('GIT_PATH: ', 'https://{7ebee1f88ec9b82612e41eb481a2bfc9b6f548d4}@github.com/peter-sipos/Learning-to-See-in-the-Dark.git')

# %%
# %cd /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation
# !git clone "{GIT_PATH}" # clone the github repository
# Out:
# /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation
# Cloning into 'Learning-to-See-in-the-Dark'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 168 (delta 1), reused 3 (delta 1), pack-reused 161
# Receiving objects: 100% (168/168), 470.42 KiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
# %cd /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation/Learning-to-See-in-the-Dark
# %pwd
# !git branch
# Out:
# /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation/Learning-to-See-in-the-Dark
# * master

# %%
# !pip install -q scipy
# !pip install -q numpy
# !pip install -q rawpy
# !pip install -q Pillow
# Out:
#      |████████████████████████████████| 655kB 4.9MB/s

# %%
# !python download_models.py
# Out:
# Dowloading Sony Model (84Mb)
# Dowloading Fuji Model (84Mb)

# %%
# !python test_Sony.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0227 15:42:38.782073 140398478858112 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0227 15:42:40.873589 140398478858112 module_wrapper.py:139] From test_Sony.py:99: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-02-27 15:42:40.875887: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020
# 10069_00_0.1s.ARW
# 10074_00_0.1s.ARW
# 10077_00_0.1s.ARW
# 10082_00_0.1s.ARW
# 10087_00_0.1s.ARW
# 10093_00_0.1s.ARW
# 10101_00_0.1s.ARW
# 10103_00_0.1s.ARW
# 10105_00_0.1s.ARW
# 10106_00_0.1s.ARW
# 10111_00_0.1s.ARW
# 10116_00_0.1s.ARW
# 10125_00_0.1s.ARW
# 10126_00_0.1s.ARW
# 10139_00_0.1s.ARW
# 10140_00_0.1s.ARW
# 10162_00_0.1s.ARW
# 10163_00_0.1s.ARW
# 10167_00_0.1s.ARW
# 10170_00_0.1s.ARW
# 10172_00_0.1s.ARW
# 10176_00_0.1s.ARW
# 10178_00_0.033s.ARW
# 10178_00_0.04s.ARW
# 10178_00_0.1s.ARW
# 10185_00_0.033s.ARW
# 10185_00_0.04s.ARW
# 10185_00_0.1s.ARW
# 10187_00_0.033s.ARW
# 10187_00_0.04s.ARW
# 10187_00_0.1s.ARW
# 10191_00_0.033s.ARW
# 10191_00_0.04s.ARW
# 10191_00_0.1s.ARW
# 10192_00_0.033s.ARW
# 10192_00_0.04s.ARW
# 10192_00_0.1s.ARW
# 10193_00_0.033s.ARW
# 10193_00_0.04s.ARW
# 10193_00_0.1s.ARW
# 10198_00_0.033s.ARW
# 10198_00_0.04s.ARW
# 10198_00_0.1s.ARW
# 10199_00_0.033s.ARW
# 10199_00_0.04s.ARW
# 10199_00_0.1s.ARW
# 10203_00_0.033s.ARW
# 10203_00_0.04s.ARW
# 10203_00_0.1s.ARW
# 10213_00_0.033s.ARW
# 10213_00_0.04s.ARW
# 10213_00_0.1s.ARW
# 10217_00_0.033s.ARW
# 10217_00_0.04s.ARW
# 10217_00_0.1s.ARW
# 10226_00_0.033s.ARW
# 10226_00_0.04s.ARW
# 10226_00_0.1s.ARW
# 10227_00_0.033s.ARW
# 10227_00_0.04s.ARW
# 10227_00_0.1s.ARW
# 10228_00_0.033s.ARW
# 10228_00_0.04s.ARW
# 10228_00_0.1s.ARW

# %%
# !ls
# Out:
#  checkpoint	       LICENSE.md			   test_Sony.py
#  dataset	       README.md			   train_Fuji.py
#  download_dataset.py   result_Sony			   train_Sony.py
#  download_models.py   'Rozbehanie zdrojového kódu.ipynb'
#  images		       test_Fuji.py

# %%
# !pwd
# Out:
# /content/drive/My Drive/Bakalárka - Peter Šípoš/Implementácia

# %%
# %cd Learning-to-See-in-the-Dark

# %%
# %cd /content/drive/My Drive/Bakalárka - Peter Šípoš/Implementácia
# Out:
# /content/drive/My Drive/Bakalárka - Peter Šípoš/Implementácia
