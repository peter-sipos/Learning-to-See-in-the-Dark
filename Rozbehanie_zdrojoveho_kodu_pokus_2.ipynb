# %%
# %cd /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation/Learning-to-See-in-the-Dark/
# Out:
# /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation/Learning-to-See-in-the-Dark

# %%
# !pip install -q scipy==1.2.0
# !pip install -q numpy
# !pip install -q rawpy
# !pip install -q Pillow
# !pip install -q matplotlib
# Out:
#      |████████████████████████████████| 26.6MB 114kB/s
# ERROR: tensorflow 2.2.0rc2 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.2.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 1.6MB 4.6MB/s

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
# !python download_models.py

# %%
# !python test_Sony.py

# %%
# !python test_residual_4000.py

# %%
# !python test_validation_and_batch_4000.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From test_validation_and_batch_4000.py:99: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-04-13 18:10:00.132503: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-13 18:10:00.185615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.186206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-13 18:10:00.186529: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-13 18:10:00.188220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-13 18:10:00.196674: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-13 18:10:00.197024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-13 18:10:00.198756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-13 18:10:00.227185: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-13 18:10:00.230969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-13 18:10:00.231083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.231659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.232148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-13 18:10:00.243796: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-04-13 18:10:00.244309: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19e0f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-13 18:10:00.244340: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-13 18:10:00.371250: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.371900: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19e1100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-13 18:10:00.371933: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-13 18:10:00.373339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.373865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-13 18:10:00.373934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-13 18:10:00.373960: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-13 18:10:00.373983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-13 18:10:00.374002: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-13 18:10:00.374021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-13 18:10:00.374040: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-13 18:10:00.374060: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-13 18:10:00.374123: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.374667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.375141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-13 18:10:00.378396: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-13 18:10:00.379968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-13 18:10:00.380000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-04-13 18:10:00.380010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-04-13 18:10:00.381303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.382131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 18:10:00.382908: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-13 18:10:00.382953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From test_validation_and_batch_4000.py:100: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From test_validation_and_batch_4000.py:32: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From test_validation_and_batch_4000.py:78: The name tf.depth_to_space is deprecated. Please use tf.compat.v1.depth_to_space instead.
#
# WARNING:tensorflow:From test_validation_and_batch_4000.py:104: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From test_validation_and_batch_4000.py:105: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# loaded ./results/2020_04_13-09_17_train_validation_and_batch.py_4000e_75i_100s/model.ckpt
# 10003_00_0.04s.ARW
# 2020-04-13 18:10:29.289814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-13 18:10:34.014197: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 10003_00_0.1s.ARW
# 10006_00_0.04s.ARW
# 10006_00_0.1s.ARW
# 10011_00_0.04s.ARW
# 10011_00_0.1s.ARW
# 10016_00_0.04s.ARW
# 10016_00_0.1s.ARW
# 10022_00_0.04s.ARW
# 10022_00_0.1s.ARW
# 10030_00_0.04s.ARW
# 10030_00_0.1s.ARW
# 10032_00_0.04s.ARW
# 10032_00_0.1s.ARW
# 10034_00_0.04s.ARW
# 10034_00_0.1s.ARW
# 10035_00_0.04s.ARW
# 10035_00_0.1s.ARW
# 10040_00_0.04s.ARW
# 10040_00_0.1s.ARW
# 10045_00_0.04s.ARW
# 10045_00_0.1s.ARW
# 10054_00_0.04s.ARW
# 10054_00_0.1s.ARW
# 10055_00_0.04s.ARW
# 10055_00_0.1s.ARW
# 10068_00_0.04s.ARW
# 10068_00_0.1s.ARW
# 10069_00_0.04s.ARW
# 10069_00_0.1s.ARW
# 10074_00_0.1s.ARW
# 10077_00_0.1s.ARW
# 10082_00_0.1s.ARW
# 10087_00_0.1s.ARW
# 10093_00_0.1s.ARW
# 10101_00_0.1s.ARW
# 10103_00_0.1s.ARW
# 10105_00_0.1s.ARW
# 10106_00_0.1s.ARW
# 10111_00_0.1s.ARW
# 10116_00_0.1s.ARW
# 10125_00_0.1s.ARW
# 10126_00_0.1s.ARW
# 10139_00_0.1s.ARW
# 10140_00_0.1s.ARW
# 10162_00_0.1s.ARW
# 10163_00_0.1s.ARW
# 10167_00_0.1s.ARW
# 10170_00_0.1s.ARW
# 10172_00_0.1s.ARW
# 10176_00_0.1s.ARW
# 10178_00_0.033s.ARW
# 10178_00_0.04s.ARW
# 10178_00_0.1s.ARW
# 10185_00_0.033s.ARW
# 10185_00_0.04s.ARW
# 10185_00_0.1s.ARW
# 10187_00_0.033s.ARW
# 10187_00_0.04s.ARW
# 10187_00_0.1s.ARW
# 10191_00_0.033s.ARW
# 10191_00_0.04s.ARW
# 10191_00_0.1s.ARW
# 10192_00_0.033s.ARW
# 10192_00_0.04s.ARW
# 10192_00_0.1s.ARW
# 10193_00_0.033s.ARW
# 10193_00_0.04s.ARW
# 10193_00_0.1s.ARW
# 10198_00_0.033s.ARW
# 10198_00_0.04s.ARW
# 10198_00_0.1s.ARW
# 10199_00_0.033s.ARW
# 10199_00_0.04s.ARW
# 10199_00_0.1s.ARW
# 10203_00_0.033s.ARW
# 10203_00_0.04s.ARW
# 10203_00_0.1s.ARW
# 10213_00_0.033s.ARW
# 10213_00_0.04s.ARW
# 10213_00_0.1s.ARW
# 10217_00_0.033s.ARW
# 10217_00_0.04s.ARW
# 10217_00_0.1s.ARW
# 10226_00_0.033s.ARW
# 10226_00_0.04s.ARW
# 10226_00_0.1s.ARW
# 10227_00_0.033s.ARW
# 10227_00_0.04s.ARW
# 10227_00_0.1s.ARW
# 10228_00_0.033s.ARW
# 10228_00_0.04s.ARW
# 10228_00_0.1s.ARW

# %%
# !python train_current_development.py

# %%
# !python train_validation_and_batch.py

# %%
# !python PSNR.py
# Out:
# Finished loading filenames.   Time=6.935
# Finished calculating PSNR for ratio 100.   Time=182.100
# Finished calculating PSNR for ratio 250.   Time=140.029
# Finished calculating PSNR for ratio 300.   Time=185.361
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average original 100: 32.66983260983117
# Average original 250: 31.67776770252076
# Average original 300: 31.601236040632887
# Average original whole: 31.958319037423202
#
# Finished loading filenames.   Time=5.920
# Finished calculating PSNR for ratio 100.   Time=134.552
# Finished calculating PSNR for ratio 250.   Time=166.110
# Finished calculating PSNR for ratio 300.   Time=229.403
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average residual_4000 100: 32.188244489392176
# Average residual_4000 250: 31.517735862379638
# Average residual_4000 300: 31.486098340338017
# Average residual_4000 whole: 31.714912603367885

# %%
# !python PSNR_orig_validation.py
# Out:
# Finished loading filenames.   Time=0.008
# Finished calculating PSNR for ratio 100.   Time=16.558
# Finished calculating PSNR for ratio 250.   Time=16.763
# Finished calculating PSNR for ratio 300.   Time=20.376
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average original 100: 32.66983260983117
# Average original 250: 31.67776770252076
# Average original 300: 31.601236040632887
# Average original whole: 31.958319037423202
#
# Finished loading filenames.   Time=0.011
# Finished calculating PSNR for ratio 100.   Time=136.685
# Finished calculating PSNR for ratio 250.   Time=129.366
# Finished calculating PSNR for ratio 300.   Time=161.607
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average validation_and_batch_4000 100: 32.41500161296576
# Average validation_and_batch_4000 250: 31.45297322941067
# Average validation_and_batch_4000 300: 31.399309901153686
# Average validation_and_batch_4000 whole: 31.73276469859457

# %%
# !python PSNR_residual_validation.py
# Out:
# Finished loading filenames.   Time=0.008
# Finished calculating PSNR for ratio 100.   Time=139.314
# Finished calculating PSNR for ratio 250.   Time=139.427
# Finished calculating PSNR for ratio 300.   Time=158.714
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average residual_4000 100: 32.188244489392176
# Average residual_4000 250: 31.517735862379638
# Average residual_4000 300: 31.486098340338017
# Average residual_4000 whole: 31.714912603367885
#
# Finished loading filenames.   Time=0.010
# Finished calculating PSNR for ratio 100.   Time=16.946
# Finished calculating PSNR for ratio 250.   Time=17.103
# Finished calculating PSNR for ratio 300.   Time=20.888
# Number of photos in ratio 100 - gt, out: 29 29
# Number of photos in ratio 250 - gt, out: 29 29
# Number of photos in ratio 300 - gt, out: 35 35
# Average validation_and_batch_4000 100: 32.41500161296576
# Average validation_and_batch_4000 250: 31.45297322941067
# Average validation_and_batch_4000 300: 31.399309901153686
# Average validation_and_batch_4000 whole: 31.73276469859457

# %%
# !ls

# %%
# !pwd
# Out:
# /content/drive/My Drive/Bakalarka-Peter_Sipos/Implementation/Learning-to-See-in-the-Dark

# %%
a = []
while(1):
    a.append('1')

# %%
# !pip install -q tensorflow==2.2.0-rc1

# %%
import tensorflow as tf
# im1 = tf.image.decode_png('./results/test_original/final/10228_00_300_gt.png')
# im2 = tf.image.decode_png('./results/test_original/final/10228_00_300_out.png')
#im2 = tf.decode_png('results/test_residual_4000/final/')

im1 = tf.image.decode_png('./results/test_original/final/')
im2 = tf.image.decode_png('./results/test_original/final/')
# Compute PSNR over tf.uint8 Tensors.
psnr2 = tf.image.psnr(im1, im2, max_val=255)
print(psnr2)
with tf.Session() as sess:  print(psnr2.shape)
# Out:
# Tensor("PSNR_7/Identity:0", shape=(), dtype=float32)
# ()
